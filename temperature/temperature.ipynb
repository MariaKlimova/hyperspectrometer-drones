# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
alum = {
    '1':[
            {
                'h': 55,
                'v': 44,
                'temp': -20
            },
            {
                'h': 53,
                'v': 67,
                'temp': 0
            },
            
            {
                'h': 55,
                'v': 70,
                'temp': 20
            },
            {
                'h': 55,
                'v': 67,
                'temp': 30
            },
            {
                'h': 40,
                'v': 51,
                'temp': 50
            },
            
        
        ],
    '2':[
            {
                'h': 46,
                'v': 64,
                'temp': -20
            },
            {
                'h': 57,
                'v': 67,
                'temp': 0
            },
            
            {
                'h': 60,
                'v': 70,
                'temp': 20
            },
            {
                'h': 60,
                'v': 70,
                'temp': 30
            },
            {
                'h': 44,
                'v': 55,
                'temp': 50
            },
        ],
        
    '3':[
            {
                'h': 36,
                'v': 41,
                'temp': -20
            },
            {
                'h':45,
                'v': 55,
                'temp': 0
            },
            {
                'h': 51,
                'v': 62,
                'temp': 20
            },
            {
                'h': 59,
                'v': 64,
                'temp': 30
            },
            {
                'h': 56,
                'v': 66,
                'temp': 50
            },
        ],
    '4':[
            {

                'h': 32,
                'v': 33,
                'temp': -20

            },
            {
                'h': 39,
                'v': 37,
                'temp': 0
            },
            {
                'h': 47,
                'v': 41,
                'temp': 20
            },
            {
                'h': 50,
                'v': 43,
                'temp': 30
            },
            {
                'h': 43,
                'v': 43,
                'temp': 50
            },
        ],
    '5':[
            {
                'h': 54,
                'v': 66,
                'temp': -20
            },
            {
                'h': 63,
                'v': 71,
                'temp': 0
            },
            
            {
                'h': 68,
                'v': 74,
                'temp': 20
            },
            {
                'h': 65,
                'v': 68,
                'temp': 30
            },
            {
                'h': 52,
                'v': 51,
                'temp': 50
            },
        ]
}

# %%
titan = {
    '1':[
            {
                'h': 21,
                'v': 34,
                'temp': -20
            },
            {
                'h': 25,
                'v': 50,
                'temp': 0
            },
            
            {
                'h': 31,
                'v': 56,
                'temp': 20
            },
            {
                'h': 36,
                'v': 57,
                'temp': 30
            },
            {
                'h': 43,
                'v': 50,
                'temp': 50
            },
            
        
        ],
    '2':[
            {
                'h': 33,
                'v': 34,
                'temp': -20
            },
            {
                'h': 44,
                'v': 45,
                'temp': 0
            },
            
            {
                'h': 54,
                'v': 53,
                'temp': 20
            },
            {
                'h': 57,
                'v': 55,
                'temp': 30
            },
            {
                'h': 50,
                'v': 44,
                'temp': 50
            },
        ],
        
    '3':[
            {
                'h': 25,
                'v': 24,
                'temp': -20
            },
            {
                'h':38,
                'v': 37,
                'temp': 0
            },
            {
                'h': 50,
                'v': 51,
                'temp': 20
            },
            {
                'h': 53,
                'v': 58,
                'temp': 30
            },
            {
                'h': 57,
                'v': 61,
                'temp': 50
            },
        ],
    '4':[
            {

                'h':17,
                'v': 16,
                'temp': -20

            },
            {
                'h': 28,
                'v': 26,
                'temp': 0
            },
            {
                'h': 40,
                'v': 36,
                'temp': 20
            },
            {
                'h': 43,
                'v': 41,
                'temp': 30
            },
            {
                'h': 55,
                'v': 50,
                'temp': 50
            },
        ],
    '5':[
            {
                'h': 32,
                'v': 52,
                'temp': -20
            },
            {
                'h': 46,
                'v': 57,
                'temp': 0
            },
            
            {
                'h': 58,
                'v': 65,
                'temp': 20
            },
            {
                'h': 51,
                'v': 70,
                'temp': 30
            },
            {
                'h': 66,
                'v': 66,
                'temp': 50
            },
        ]
}

# %%
alum2={
    '1':[
            {
                'h': 50,
                'v': 41,
                'temp': -20
            },
            {
                'h': 53,
                'v': 51,
                'temp': 0
            },
            
            {
                'h': 57,
                'v': 55,
                'temp': 20
            },
            {
                'h': 67,
                'v': 57,
                'temp': 30
            },
            {
                'h': 59,
                'v': 64,
                'temp': 50
            },
        
        ],
    '2':[
            {
                'h': 48,
                'v': 47,
                'temp': -20
            },
            {
                'h': 59,
                'v': 51,
                'temp': 0
            },
            
            {
                'h': 62,
                'v': 58,
                'temp': 20
            },
            {
                'h': 69,
                'v': 63,
                'temp': 30
            },
            {
                'h': 70,
                'v': 64,
                'temp': 50
            },
        ],
        
    '3':[
            {
                'h': 39,
                'v': 37,
                'temp': -20
            },
            {
                'h':51,
                'v': 44,
                'temp': 0
            },
            {
                'h': 56,
                'v': 52,
                'temp': 20
            },
            {
                'h': 60,
                'v': 56,
                'temp': 30
            },
            {
                'h': 69,
                'v': 68,
                'temp': 50
            },
        ],
    '4':[
            {

                'h':39,
                'v': 30,
                'temp': -20

            },
            {
                'h': 45,
                'v': 34,
                'temp': 0
            },
            {
                'h': 58,
                'v': 44,
                'temp': 20
            },
            {
                'h': 59,
                'v': 46,
                'temp': 30
            },
            {
                'h': 71,
                'v': 65,
                'temp': 50
            },
        ],
    '5':[
            {
                'h': 43,
                'v': 52,
                'temp': -20
            },
            {
                'h': 62,
                'v': 53,
                'temp': 0
            },
            
            {
                'h': 73,
                'v': 65,
                'temp': 20
            },
            {
                'h': 67,
                'v': 61,
                'temp': 30
            },
            {
                'h': 77,
                'v': 71,
                'temp': 50
            },
        ]
}

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
plt.title('Horizontal')
fig1.set_size_inches(15,10)
mira_1_h = [el['h'] for el in alum['1']]
mira_2_h = [el['h'] for el in alum['2']]
mira_3_h = [el['h'] for el in alum['3']]
mira_4_h = [el['h'] for el in alum['4']]
mira_5_h = [el['h'] for el in alum['5']]
mira_1t_h = [el['h'] for el in alum2['1']]
mira_2t_h = [el['h'] for el in alum2['2']]
mira_3t_h = [el['h'] for el in alum2['3']]
mira_4t_h = [el['h'] for el in alum2['4']]
mira_5t_h = [el['h'] for el in alum2['5']]
#ax1.plot(x, mira_1_h, color='b', label='1', linestyle=':') #linestyle=':'
ax1.plot(x, mira_2_h, color='g', label='2', linestyle=':')
#ax1.plot(x, mira_3_h, color='r', label='3', linestyle=':')
#ax1.plot(x, mira_4_h, color='m', label='4', linestyle=':')
#ax1.plot(x, mira_5_h, color='c', label='5', linestyle=':')
#ax1.plot(x, mira_1t_h, color='b', label='1new') #linestyle=':'
ax1.plot(x, mira_2t_h, color='g', label='2new')
#ax1.plot(x, mira_3t_h, color='r', label='3new')
#ax1.plot(x, mira_4t_h, color='m', label='4new')
#ax1.plot(x, mira_5t_h, color='c', label='5new')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
plt.title('Vertical')
fig1.set_size_inches(15,10)
mira_1_h = [el['v'] for el in alum['1']]
mira_2_h = [el['v'] for el in alum['2']]
mira_3_h = [el['v'] for el in alum['3']]
mira_4_h = [el['v'] for el in alum['4']]
mira_5_h = [el['v'] for el in alum['5']]
mira_1t_h = [el['v'] for el in alum2['1']]
mira_2t_h = [el['v'] for el in alum2['2']]
mira_3t_h = [el['v'] for el in alum2['3']]
mira_4t_h = [el['v'] for el in alum2['4']]
mira_5t_h = [el['v'] for el in alum2['5']]
#ax1.plot(x, mira_1_h, color='b', label='1 old', linestyle=':') #linestyle=':'
ax1.plot(x, mira_2_h, color='g', label='2 old', linestyle=':')
#ax1.plot(x, mira_3_h, color='r', label='3 old', linestyle=':')
#ax1.plot(x, mira_4_h, color='m', label='4 old', linestyle=':')
#ax1.plot(x, mira_5_h, color='c', label='5 old', linestyle=':')
#ax1.plot(x, mira_1t_h, color='b', label='1 new') #linestyle=':'
ax1.plot(x, mira_2t_h, color='g', label='2 new')
#ax1.plot(x, mira_3t_h, color='r', label='3 new')
#ax1.plot(x, mira_4t_h, color='m', label='4 new')
#ax1.plot(x, mira_5t_h, color='c', label='5 new')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Vertical')
fig1.set_size_inches(15,10)
mira_1_v = [el['v'] for el in alum['1']]
mira_2_v = [el['v'] for el in alum['2']]
mira_3_v = [el['v'] for el in alum['3']]
mira_4_v = [el['v'] for el in alum['4']]
mira_5_v = [el['v'] for el in alum['5']]
mira_1t_v = [el['v'] for el in titan['1']]
mira_2t_v = [el['v'] for el in titan['2']]
mira_3t_v = [el['v'] for el in titan['3']]
mira_4t_v = [el['v'] for el in titan['4']]
mira_5t_v = [el['v'] for el in titan['5']]
#ax1.plot(x, mira_1_v, color='b', label='1', linestyle=':')
#ax1.plot(x, mira_2_v, color='g', label='2', linestyle=':')
#ax1.plot(x, mira_3_v, color='r', label='3', linestyle=':')
#ax1.plot(x, mira_4_v, color='m', label='4', linestyle=':')
ax1.plot(x, mira_5_v, color='c', label='5', linestyle=':')
#ax1.plot(x, mira_1t_v, color='b', label='1t')
#ax1.plot(x, mira_2t_v, color='g', label='2t')
#ax1.plot(x, mira_3t_v, color='r', label='3t')
#ax1.plot(x, mira_4t_v, color='m', label='4t')
ax1.plot(x, mira_5t_v, color='c', label='5t')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Горизонтальное направление')
fig1.set_size_inches(15,10)
mira_1_v = [el['h'] for el in alum['1']]
mira_2_v = [el['h'] for el in alum['2']]
mira_3_v = [el['h'] for el in alum['3']]
mira_4_v = [el['h'] for el in alum['4']]
mira_5_v = [el['h'] for el in alum['5']]
mira_1t_v = [el['h'] for el in titan['1']]
mira_2t_v = [el['h'] for el in titan['2']]
mira_3t_v = [el['h'] for el in titan['3']]
mira_4t_v = [el['h'] for el in titan['4']]
mira_5t_v = [el['h'] for el in titan['5']]
ax1.plot(x, mira_1_v, color='b', label='1 Al', linestyle=':')
ax1.plot(x, mira_2_v, color='g', label='2 Al', linestyle=':')
ax1.plot(x, mira_3_v, color='r', label='3 Al', linestyle=':')
ax1.plot(x, mira_4_v, color='m', label='4 Al', linestyle=':')
ax1.plot(x, mira_5_v, color='c', label='5 Al', linestyle=':')
ax1.plot(x, mira_1t_v, color='b', label='1 Ti')
ax1.plot(x, mira_2t_v, color='g', label='2 Ti')
ax1.plot(x, mira_3t_v, color='r', label='3 Ti')
ax1.plot(x, mira_4t_v, color='m', label='4 Ti')
ax1.plot(x, mira_5t_v, color='c', label='5 Ti')
ax1.set_xlabel('Температура')
ax1.set_ylabel('ФПМ')
ax1.legend()

# %%
a = [2,4,5]
b = [4, 5, 3]
c = np.array([a, b])
np.average(c.T[0])
# Out:
# 3.0

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Горизонтальное направление')
fig1.set_size_inches(15,10)
mira_1_v = [el['h'] for el in alum['1']]
mira_2_v = [el['h'] for el in alum['2']]
mira_3_v = [el['h'] for el in alum['3']]
mira_4_v = [el['h'] for el in alum['4']]
mira_5_v = [el['h'] for el in alum['5']]
mira_1t_v = [el['h'] for el in titan['1']]
mira_2t_v = [el['h'] for el in titan['2']]
mira_3t_v = [el['h'] for el in titan['3']]
mira_4t_v = [el['h'] for el in titan['4']]
mira_5t_v = [el['h'] for el in titan['5']]

miras_al = np.array([mira_1_v, mira_2_v,mira_3_v,mira_4_v,mira_5_v,]).T
mira_al = [np.average(ar) for ar in miras_al]
miras_ti = np.array([mira_1t_v, mira_2t_v,mira_3t_v,mira_4t_v,mira_5t_v,]).T
mira_ti = [np.average(ar) for ar in miras_ti]
ax1.plot(x, mira_al, color='b', label='Al - среднее')
ax1.plot(x, mira_ti, color='c', label='Ti - среднее')
ax1.set_xlabel('Температура')
ax1.set_ylabel('ФПМ')
ax1.legend()

# %%
mira_al
# Out:
# [43.8, 54.0, 61.2, 64.4, 69.2]

# %%
mira_ti
# Out:
# [25.6, 36.2, 46.6, 48.0, 54.2]

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Вертикальное направление')
fig1.set_size_inches(15,10)
mira_1_v = [el['v'] for el in alum['1']]
mira_2_v = [el['v'] for el in alum['2']]
mira_3_v = [el['v'] for el in alum['3']]
mira_4_v = [el['v'] for el in alum['4']]
mira_5_v = [el['v'] for el in alum['5']]
mira_1t_v = [el['v'] for el in titan['1']]
mira_2t_v = [el['v'] for el in titan['2']]
mira_3t_v = [el['v'] for el in titan['3']]
mira_4t_v = [el['v'] for el in titan['4']]
mira_5t_v = [el['v'] for el in titan['5']]
ax1.plot(x, mira_1_v, color='b', label='1 Al', linestyle=':')
ax1.plot(x, mira_2_v, color='g', label='2 Al', linestyle=':')
ax1.plot(x, mira_3_v, color='r', label='3 Al', linestyle=':')
ax1.plot(x, mira_4_v, color='m', label='4 Al', linestyle=':')
ax1.plot(x, mira_5_v, color='c', label='5 Al', linestyle=':')
ax1.plot(x, mira_1t_v, color='b', label='1 Ti')
ax1.plot(x, mira_2t_v, color='g', label='2 Ti')
ax1.plot(x, mira_3t_v, color='r', label='3 Ti')
ax1.plot(x, mira_4t_v, color='m', label='4 Ti')
ax1.plot(x, mira_5t_v, color='c', label='5 Ti')
ax1.set_xlabel('Температура')
ax1.set_ylabel('ФПМ')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Вертикальное направление')
fig1.set_size_inches(15,10)
mira_1_v = [el['v'] for el in alum['1']]
mira_2_v = [el['v'] for el in alum['2']]
mira_3_v = [el['v'] for el in alum['3']]
mira_4_v = [el['v'] for el in alum['4']]
mira_5_v = [el['v'] for el in alum['5']]
mira_1t_v = [el['v'] for el in titan['1']]
mira_2t_v = [el['v'] for el in titan['2']]
mira_3t_v = [el['v'] for el in titan['3']]
mira_4t_v = [el['v'] for el in titan['4']]
mira_5t_v = [el['v'] for el in titan['5']]

miras_al = np.array([mira_1_v, mira_2_v,mira_3_v,mira_4_v,mira_5_v,]).T
mira_al = [np.average(ar) for ar in miras_al]
miras_ti = np.array([mira_1t_v, mira_2t_v,mira_3t_v,mira_4t_v,mira_5t_v,]).T
mira_ti = [np.average(ar) for ar in miras_ti]
ax1.plot(x, mira_al, color='b', label='Al - среднее')
ax1.plot(x, mira_ti, color='c', label='Ti -среднее')
ax1.set_xlabel('Температура')
ax1.set_ylabel('ФПМ')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in titan['1']]
plt.title('Horizontal')
mira_1_h = [el['h'] for el in titan['1']]
mira_2_h = [el['h'] for el in titan['2']]
mira_3_h = [el['h'] for el in titan['3']]
mira_4_h = [el['h'] for el in titan['4']]
mira_5_h = [el['h'] for el in titan['5']]
ax1.plot(x, mira_1_h, color='b', label='1') #linestyle=':'
ax1.plot(x, mira_2_h, color='g', label='2')
ax1.plot(x, mira_3_h, color='r', label='3')
ax1.plot(x, mira_4_h, color='m', label='4')
ax1.plot(x, mira_5_h, color='c', label='5')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in titan['1']]
mira_1_v = [el['v'] for el in titan['1']]
plt.title('Vertical')
mira_1_v = [el['v'] for el in titan['1']]
mira_2_v = [el['v'] for el in titan['2']]
mira_3_v = [el['v'] for el in titan['3']]
mira_4_v = [el['v'] for el in titan['4']]
mira_5_v = [el['v'] for el in titan['5']]
ax1.plot(x, mira_1_v, color='b', label='1')
ax1.plot(x, mira_2_v, color='g', label='2')
ax1.plot(x, mira_3_v, color='r', label='3')
ax1.plot(x, mira_4_v, color='m', label='4')
ax1.plot(x, mira_5_v, color='c', label='5')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum2['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Vertical')
mira_1_v = [el['v'] for el in alum2['1']]
mira_2_v = [el['v'] for el in alum2['2']]
mira_3_v = [el['v'] for el in alum2['3']]
mira_4_v = [el['v'] for el in alum2['4']]
mira_5_v = [el['v'] for el in alum2['5']]
ax1.plot(x, mira_1_v, color='b', label='1')
ax1.plot(x, mira_2_v, color='g', label='2')
ax1.plot(x, mira_3_v, color='r', label='3')
ax1.plot(x, mira_4_v, color='m', label='4')
ax1.plot(x, mira_5_v, color='c', label='5')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum2['1']]
mira_1_v = [el['h'] for el in alum2['1']]
plt.title('Horizontal')
mira_1_v = [el['h'] for el in alum2['1']]
mira_2_v = [el['h'] for el in alum2['2']]
mira_3_v = [el['h'] for el in alum2['3']]
mira_4_v = [el['h'] for el in alum2['4']]
mira_5_v = [el['h'] for el in alum2['5']]
ax1.plot(x, mira_1_v, color='b', label='1')
ax1.plot(x, mira_2_v, color='g', label='2')
ax1.plot(x, mira_3_v, color='r', label='3')
ax1.plot(x, mira_4_v, color='m', label='4')
ax1.plot(x, mira_5_v, color='c', label='5')
ax1.legend()

# %%
temps = [-20,0,20,30,50]
old = []
new = []
for temp in temps:
    sum_old = 0
    sum_new = 0
    for i in range(1,6):
        for el in alum[str(i)]:
            
            if (el['temp']==temp):
                sum_old += el['h']+el['v']
        for el in alum2[str(i)]:
            
            if (el['temp']==temp):
                sum_new += el['h']+el['v']
    old.append(sum_old//5)
    new.append(sum_new//5)
old,new
# Out:
# ([94, 110, 119, 120, 100], [85, 100, 116, 121, 135])

# %%
fig1, ax1 = plt.subplots(1)
x = temps
plt.title('Оба направления')
fig1.set_size_inches(15,10)
ax1.plot(x, old, color='b', label='Без приставки')
ax1.plot(x, new, color='r', label='С приставкой')
ax1.legend()

# %%
temps = [-20,0,20,30,50]
oldh = []
newh = []
for temp in temps:
    sum_old = 0
    sum_new = 0
    for i in range(1,6):
        for el in alum[str(i)]:
            
            if (el['temp']==temp):
                sum_old += el['h']
        for el in alum2[str(i)]:
            
            if (el['temp']==temp):
                sum_new += el['h']
    oldh.append(sum_old//5)
    newh.append(sum_new//5)
old,new
# Out:
# ([94, 110, 119, 120, 100], [85, 100, 116, 121, 135])

# %%
temps = [-20,0,20,30,50]
oldv = []
newv = []
for temp in temps:
    sum_old = 0
    sum_new = 0
    for i in range(1,6):
        for el in alum[str(i)]:
            
            if (el['temp']==temp):
                sum_old += el['v']
        for el in alum2[str(i)]:
            
            if (el['temp']==temp):
                sum_new += el['v']
    oldv.append(sum_old//5)
    newv.append(sum_new//5)
old,new
# Out:
# ([94, 110, 119, 120, 100], [85, 100, 116, 121, 135])

# %%
fig1, ax1 = plt.subplots(1)
x = temps
plt.title('Горизонтальное направление')
fig1.set_size_inches(15,10)
ax1.plot(x, oldh, color='b', label='Без приставки')
ax1.plot(x, newh, color='r', label='С приставкой')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = temps
plt.title('Вертикальное направление')
fig1.set_size_inches(15,10)
ax1.plot(x, oldv, color='b', label='Без приставки')
ax1.plot(x, newv, color='r', label='С приставкой')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = temps
plt.title('Vertical and horizontal')
fig1.set_size_inches(15,10)
ax1.plot(x, oldv, color='b', label='old vert')
ax1.plot(x, newv, color='r', label='new vert')
ax1.plot(x, oldh, color='b', label='old hor', linestyle='--')
ax1.plot(x, newh, color='r', label='new hor', linestyle='--')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Горизонтальное направление')
fig1.set_size_inches(15,10)
mira_1_v = [el['h'] for el in alum['1']]
mira_2_v = [el['h'] for el in alum['2']]
mira_3_v = [el['h'] for el in alum['3']]
mira_4_v = [el['h'] for el in alum['4']]
mira_5_v = [el['h'] for el in alum['5']]
mira_1n_v = [el['h'] for el in alum2['1']]
mira_2n_v = [el['h'] for el in alum2['2']]
mira_3n_v = [el['h'] for el in alum2['3']]
mira_4n_v = [el['h'] for el in alum2['4']]
mira_5n_v = [el['h'] for el in alum2['5']]
ax1.plot(x, mira_1_v, color='b', label='1 без приставки', linestyle=':')
ax1.plot(x, mira_2_v, color='g', label='2 без приставки', linestyle=':')
ax1.plot(x, mira_3_v, color='r', label='3 без приставки', linestyle=':')
ax1.plot(x, mira_4_v, color='m', label='4 без приставки', linestyle=':')
ax1.plot(x, mira_5_v, color='c', label='5 без приставки', linestyle=':')
ax1.plot(x, mira_1n_v, color='b', label='1 с приставкой')
ax1.plot(x, mira_2n_v, color='g', label='2 с приставкой')
ax1.plot(x, mira_3n_v, color='r', label='3 с приставкой')
ax1.plot(x, mira_4n_v, color='m', label='4 с приставкой')
ax1.plot(x, mira_5n_v, color='c', label='5 с приставкой')
ax1.set_xlabel('Температура')
ax1.set_ylabel('ФПМ')
ax1.legend()

# %%
fig1, ax1 = plt.subplots(1)
x = [el['temp'] for el in alum['1']]
mira_1_v = [el['v'] for el in alum2['1']]
plt.title('Вертикальное направление')
fig1.set_size_inches(15,10)
mira_1_v = [el['v'] for el in alum['1']]
mira_2_v = [el['v'] for el in alum['2']]
mira_3_v = [el['v'] for el in alum['3']]
mira_4_v = [el['v'] for el in alum['4']]
mira_5_v = [el['v'] for el in alum['5']]
mira_1n_v = [el['v'] for el in alum2['1']]
mira_2n_v = [el['v'] for el in alum2['2']]
mira_3n_v = [el['v'] for el in alum2['3']]
mira_4n_v = [el['v'] for el in alum2['4']]
mira_5n_v = [el['v'] for el in alum2['5']]
ax1.plot(x, mira_1_v, color='b', label='1 без приставки', linestyle=':')
ax1.plot(x, mira_2_v, color='g', label='2 без приставки', linestyle=':')
ax1.plot(x, mira_3_v, color='r', label='3 без приставки', linestyle=':')
ax1.plot(x, mira_4_v, color='m', label='4 без приставки', linestyle=':')
ax1.plot(x, mira_5_v, color='c', label='5 без приставки', linestyle=':')
ax1.plot(x, mira_1n_v, color='b', label='1 с приставкой')
ax1.plot(x, mira_2n_v, color='g', label='2 с приставкой')
ax1.plot(x, mira_3n_v, color='r', label='3 с приставкой')
ax1.plot(x, mira_4n_v, color='m', label='4 с приставкой')
ax1.plot(x, mira_5n_v, color='c', label='5 с приставкой')
ax1.set_xlabel('Температура')
ax1.set_ylabel('ФПМ')
ax1.legend()
